# %% [markdown]
# <a href="https://colab.research.google.com/github/sylviatobing/TB2.VISUALISASI-DATA/blob/main/tb2_visualisasi_datai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. keuntungan dan kerugian menggunakan library1

# %% [markdown]
# numpy

# %% [markdown]
# keuntungan
#
# 1. Melakukan operasi komputasi terhadap data lebih mudah
#
# 2. ndexing dan slicing lebih cepat dan lebih mudah
#
# 3. Konversi data lebih cepat
#
# kekurangan
#
# 1. Semua item dalam NumPy array harus memiliki tipe data yang sama
#
# 2.
# Kolom dan Row hanya bisa direfer menggunakan angka, jadi kita harus bolak balik memastikan nama kolom XXX untuk kolom nomor Y, dll

# %% [markdown]
# pandas

# %% [markdown]
# keuntungan
#
# 1. Pandas menyediakan struktur data yang kuat dan fleksibel seperti DataFrame, yang memungkinkan manipulasi data tabular yang mudah dan efisien.
#
# 2. Memiliki fitur kuat untuk membersihkan, merapikan, dan mengubah format data yang kompleks.
#
# 3. menyediakan fungsionalitas SQL-like untuk melakukan operasi penggabungan, penyaringan, dan agregasi data
#
# kekurangan
#
# 1. DataFrames di Pandas memerlukan lebih banyak memori dibandingkan dengan struktur data yang lebih sederhana seperti array NumPy.
#
# 2. Performa Pandas mungkin kurang efisien ketika berurusan dengan volume data yang sangat besar.

# %% [markdown]
# Matplotlib
#
# keuntungan
#
# 1.Matplotlib adalah library yang kuat untuk visualisasi data dalam Python.
#
# 2. memiliki antarmuka yang sederhana dan intuitif untuk membuat berbagai jenis plot, seperti scatter plot, line plot, bar plot, histogram, dan lainnya.
#
# kekurangan
#
# 1. Pembuatan plot yang sangat kompleks atau interaktif mungkin memerlukan lebih banyak kode dan konfigurasi yang rumit.
#
# 2. Memerlukan pemahaman dasar tentang konsep visualisasi data.
#
# seaborn
#
# keuntungan
#
# 1. ampilan yang menarik dan estetis. 2, Integrasi yang baik dengan Pandas.
#
# 2. Memiliki antarmuka yang sederhana untuk membuat plot kompleks.
#
# kekurangan
#
# 1. Kurang fleksibel dalam melakukan kustomisasi yang kompleks.
#
# 2. Beberapa plot memerlukan konfigurasi yang rumit.
#
# 3. Tidak mendukung plot 3D secara langsung.
#
#
#   2. Tuliskan syntax sederhana yang memanggil library memuat data dan syntax yang memuat data tersebut.
#
#
# 1. import math
#
# 2. import statistics
#
# 3. import numpy as np
#
# 4. import scipy.stats
#
# 5. import pandas as pd
#
#
#   3. Jelaskan dengan menggunakan bahasa Anda sendiri apakah yang dimaksud dengan konsep kaidah Exploratory Data Analysis (EDA), dan kaidah filosofi dari Exploratory Data Analysis (EDA).
#
#
# Exploratory Data Analysis (EDA) adalah seperangkat teknik yang dikembangkan oleh John Tukey pada tahun 1970. Filosofi di balik pendekatan ini adalah untuk mengeksplorasi data sebelum membangun model. Tukey mendorong para ahli statistik untuk mengeksplorasi data, dan mungkin merumuskan hipotesis yang dapat mengarah pada pengumpulan data baru dan eksperimen
#
# 1. Menjelajahi data secara sistematis dan teratur.
#
# 2. Menggunakan metode grafis untuk mengeksplorasi data.
#
# 3. menggunakan metode statistik untuk mengeksplorasi data.
#
# 4. Membuat kesimpulan yang didasarkan pada hasil eksplorasi data.
#
#   4. penjelasan Konsep Univariate, bivariate, multivariate
#
# a. univariate adalah analisa yang dilakukan menganalisis tiap variabel dari hasil penelitian. Analisa univariat berfungsi untuk meringkas kumpulan data hasil pengukuran sedemikian rupa sehingga kumpulan data tersebut berubah menjadi informasi yang berguna.
#
# b. Bivariate adalah analisis secara simultan dari dua variabel. Hal ini biasanya dilakukan untuk melihat apakah satu variabel. Analisis bivariate terdiri atas metode-metode statistik inferensial yang digunakan untuk menganalisis data dua variabel penelitian.
#
# c.multivariate merupakan objek kajian pada statistika yang mempelajari perilaku dan hubungan antara dua atau lebih variabel. Dasar dari kajian ini adalah analisis korelasi dan analisis regresi untuk dua variabel. Prinsip yang sama kemudian dikembangkan untuk lebih dari dua variabel.
#
#
#   5. Dalam konsep pemilihan warna pada grafik. Jelaskan konsep dasar pemilihan desain warna.
#
# a. Analisis data yang telah dikumpulkan untuk menentukan kebutuhan penggunaan warna yang beragam.
#
# b. Evaluasi visualisasi lain untuk menentukan palet warna yang tepat.
#
# c. Batasi variasi warna agar tidak terlalu banyak.
#
# d. elompokkan data yang serupa.
#
# e. Pertimbangkan jenis palet warna yang digunakan.
#
# f.Tentukan warna untuk nilai-nilai tertentu.
#
# g. Soroti titik data penting.
#
# h. Tentukan latar belakang warna yang tepat

# %% [markdown]
# essay

# %%
# !pip install scikit-surprise
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score
import surprise
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3096296 sha256=1e2fc1f77cbf9b82632a701f1bc6c8d0eec743d713814d69a148eb2bcb2c7e96
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
df = pd.read_csv('employee.csv')
df.head()
# Out:
#    Unnamed: 0  EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0           0               1       Yes   41      Travel_Rarely       1102
# 1           1               2        No   49  Travel_Frequently        279
# 2           2               3       Yes   37      Travel_Rarely       1373
# 3           3               4        No   33  Travel_Frequently       1392
# 4           4               5        No   27      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  ...  \
# 0                   Sales                 1          2  Life Sciences  ...
# 1  Research & Development                 8          1  Life Sciences  ...
# 2  Research & Development                 2          2          Other  ...
# 3  Research & Development                 3          4  Life Sciences  ...
# 4  Research & Development                 2          1        Medical  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.drop(['EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df["Attrition"] = label.fit_transform(df.Attrition)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 2940 non-null   int64
#  1   Age                       2940 non-null   int64
#  2   BusinessTravel            2940 non-null   object
#  3   DailyRate                 2940 non-null   int64
#  4   Department                2940 non-null   object
#  5   DistanceFromHome          2940 non-null   int64
#  6   Education                 2940 non-null   int64
#  7   EducationField            2940 non-null   object
#  8   EnvironmentSatisfaction   2940 non-null   int64
#  9   Gender                    2940 non-null   object
#  10  HourlyRate                2940 non-null   int64
#  11  JobInvolvement            2940 non-null   int64
#  12  JobLevel                  2940 non-null   int64
#  13  JobRole                   2940 non-null   object
# ...

# %%
#confusion matrix
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":7})
# Out:
# <ipython-input-8-fc0a4c1b8001>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":7})
# <Axes: >

# %%
# C. Analisa Korelasi positif dan negatif
df.drop('Attrition', axis=1).corrwith(df.Attrition).plot(kind='barh', figsize=(15,10))
# Out:
# <ipython-input-9-1a89228d7b47>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop('Attrition', axis=1).corrwith(df.Attrition).plot(kind='barh', figsize=(15,10))
# <Axes: >

# %%
df.drop('Attrition', axis=1).corrwith(df.Attrition).sort_values().plot(kind='barh', figsize=(10, 10))
# Out:
# <ipython-input-10-386f403fca1e>:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop('Attrition', axis=1).corrwith(df.Attrition).sort_values().plot(kind='barh', figsize=(10, 10))
# <Axes: >

# %%
#prepare the training set
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV

X = df.drop('Attrition', axis=1)
y = df['Attrition']

# Perform one-hot encoding for categorical variables
categorical_cols = X.select_dtypes(include='object').columns
encoder = OneHotEncoder(sparse_output=False, drop='first')
X_encoded = pd.DataFrame(encoder.fit_transform(X[categorical_cols]))
X_encoded.columns = encoder.get_feature_names_out(categorical_cols)
X.drop(categorical_cols, axis=1, inplace=True)
X = pd.concat([X, X_encoded], axis=1)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2%}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 83.79%
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       737
#            1       0.67      0.03      0.05       145
#
#     accuracy                           0.84       882
#    macro avg       0.75      0.51      0.48       882
# weighted avg       0.81      0.84      0.77       882
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
stay = (Y_train.value_counts()[0] / Y_train.shape)[0]
leave = (Y_train.value_counts()[1] / Y_train.shape)[0]

# %%
## e. feature Engineering implementation
print("===============TRAIN=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")

stay = (Y_test.value_counts()[0] / Y_test.shape)[0]
leave = (Y_test.value_counts()[1] / Y_test.shape)[0]

print("===============TEST=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")
# Out:
# ===============TRAIN=================
# Staying Rate: 83.87%
# Leaving Rate: 16.13%
# ===============TEST=================
# Staying Rate: 83.90%
# Leaving Rate: 16.10%

# %%
## f. Cross validation
from sklearn.linear_model import LogisticRegression

# %%
lr_clf = LogisticRegression(solver='liblinear', penalty='l1')
lr_clf.fit(X_train, Y_train)
valuate(lr_clf, X_train, X_test, Y_train, Y_test)
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
##g. plot_precision_recall vs threshold, plot roc_curve, dan tentukan nilai roc_auc_score

from sklearn.metrics import precision_recall_curve, roc_curve

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    plt.plot(thresholds, recalls[:-1], "g--", label="Recall")
    plt.xlabel("Threshold")
    plt.legend(loc="upper left")
    plt.title("Precision/Recall Tradeoff")


def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], "k--")
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')


precisions, recalls, thresholds = precision_recall_curve(Y_test, lr_clf.predict(X_test))
plt.figure(figsize=(14, 25))
plt.subplot(4, 2, 1)
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)

plt.subplot(4, 2, 2)
plt.plot(precisions, recalls)
plt.xlabel("Precision")
plt.ylabel("Recall")
plt.title("PR Curve: precisions/recalls tradeoff");

plt.subplot(4, 2, 3)
fpr, tpr, thresholds = roc_curve(Y_test, lr_clf.predict(X_test))
plot_roc_curve(fpr, tpr)
